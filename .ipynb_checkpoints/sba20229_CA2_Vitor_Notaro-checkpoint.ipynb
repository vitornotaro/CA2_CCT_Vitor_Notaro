# %% [markdown]
# <img src ='CCT_logo.jpg'/>

# %% [markdown]
# ## MSc in Data Analytics ##
#
#
# ### Individual Project CA2
#
# Author:
#
# |Student Name | Student Number | Email address |
# |:-|:-:|:-:|
# | Vitor Notaro | sba20229 | vitornotaro34@gmail.com
#
# Lecturer:
#
# |Lecturer Name | Module | Email address |
# |:-|:-:|:-:|
# | David McQuaid | Data Preparation & Visualisation for Data Analytics | dmcquaid@cct.ie |
# | David McQuaid | Programming for Data Analytics | dmcquaid@cct.ie |
# | Dr. Muhammad Iqbal | Machine Learning for Data Analytics | miqbal@cct.ie |
# | Marina Iantorno | Statistics for Data Analytics | miantorno@cct.ie |
#
# ### Table of contents:
#
# 1. [CA1 Information](#first-bullet)
# 2. [Initial Exploratory and Data Analysis](#second-bullet)
# 3. [Statistics Questions ](#third-bullet)
# 4. [Folium for Visualization (Dublin Bike Map) ](#fourth-bullet)
# 5. [Data Preparation and Feature Engineering ](#fiveth-bullet)
# 6. [Re-Shaping Data and Build M Learning Models ](#sixth-bullet)
# 7. [Dimensionality Reduction using Principal Components Analyses](#seventh-bullet)
# 8. [Hierarchy Clustering](#eighth-bullet)
# 9. [KMeans Clustering](#nineth-bullet)
# 10. [Comparing models with silhouette score](#tenth-bullet)
# 11. [Imputing K Means Labels and evaluating results with Data Visualization](#eleventh-bullet)
# 12. [Conclusions](#twelveth-bullet)
# 13. [References](#thirteenth-bullet)

# %% [markdown]
# ##  Initial Exploratory and Data Analysis

# %%
# Importing libraries
import pandas as pd
import numpy as np
#from dataprep.eda import create_report
import datetime as dt
import warnings
warnings.filterwarnings('ignore')
warnings.warn('ignore')

# %%
# Using Pandas to read the dataset.
df = pd.read_csv("data/Dataset_DG_AGRI-JRC_-_Production__trade_and_apparent_use__EU-27_.csv")
# Using head() to visualize the top 5 rows
df.head(5)
# Out:
#    Country Country (NUTS Code) Country (Description)       Commodity  \
# 0  Austria                  AT                   NaN  ACIDIFIED MILK
# 1  Austria                  AT                   NaN  ACIDIFIED MILK
# 2  Austria                  AT                   NaN  ACIDIFIED MILK
# 3  Austria                  AT                   NaN  ACIDIFIED MILK
# 4  Austria                  AT                   NaN  ACIDIFIED MILK
#
#   Commodity (Type) Commodity (Primary product)  Year  \
# 0            DAIRY                         NaN  2002
# 1            DAIRY                         NaN  2003
# 2            DAIRY                         NaN  2004
# 3            DAIRY                         NaN  2005
# 4            DAIRY                         NaN  2006
#
#    Apparent use (THOUSAND TONS)  Apparent use (THOUSAND TONS (C.W.E.))  \
# 0                    139.610841                                    NaN
# 1                    146.427460                                    NaN
# 2                    140.327465                                    NaN
# 3                    148.229900                                    NaN
# 4                    163.499156                                    NaN
#
#    Apparent use (THOUSAND HECTOLITRES)  ...  Population (THOUSAND HEAD)  \
# 0                                  NaN  ...                         NaN
# 1                                  NaN  ...                         NaN
# 2                                  NaN  ...                         NaN
# 3                                  NaN  ...                         NaN
# 4                                  NaN  ...                         NaN
#
#    Production (THOUSAND TONS)  Production (THOUSAND HECTOLITRES)  \
# 0                      190.69                                NaN
# 1                      209.20                                NaN
# 2                      216.10                                NaN
# 3                      235.28                                NaN
# 4                      264.78                                NaN
#
#    Production of primary product (THOUSAND TONS)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Production (from dairy cows) (THOUSAND TONS)  Yield (animals) (KG/HEAD)  \
# 0                                           NaN                        NaN
# 1                                           NaN                        NaN
# 2                                           NaN                        NaN
# 3                                           NaN                        NaN
# 4                                           NaN                        NaN
#
#    Yield (crops) (TONNE/HA)  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#    Yield of secondary product (KG PER TONNE OF PRIMARY PRODUCT)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Yield (HECTOLITRES PER HECTARE)  Yield of primary product (TONNE/HA)
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
#
# [5 rows x 46 columns]

# %% [markdown]
# Talk About Dairy Products

# %%
df= df[df["Commodity (Type)"]=="DAIRY"]
df =df[df['Country']!="EU"]
df = df[df["Year"]>=2000]
df= df[df["Year"]<=2020]
df = df[df["Commodity"]!="WHOLE MILK POWDER"]
df = df[df["Commodity"]!="BUTTERMILK"]

# %%
df
# Out:
#        Country Country (NUTS Code) Country (Description)       Commodity  \
# 0      Austria                  AT                   NaN  ACIDIFIED MILK
# 1      Austria                  AT                   NaN  ACIDIFIED MILK
# 2      Austria                  AT                   NaN  ACIDIFIED MILK
# 3      Austria                  AT                   NaN  ACIDIFIED MILK
# 4      Austria                  AT                   NaN  ACIDIFIED MILK
# ...        ...                 ...                   ...             ...
# 28979   Sweden                  SE                   NaN    TOTAL CHEESE
# 28980   Sweden                  SE                   NaN    TOTAL CHEESE
# 28981   Sweden                  SE                   NaN    TOTAL CHEESE
# 28982   Sweden                  SE                   NaN    TOTAL CHEESE
# 28983   Sweden                  SE                   NaN    TOTAL CHEESE
#
#       Commodity (Type) Commodity (Primary product)  Year  \
# 0                DAIRY                         NaN  2002
# 1                DAIRY                         NaN  2003
# 2                DAIRY                         NaN  2004
# 3                DAIRY                         NaN  2005
# 4                DAIRY                         NaN  2006
# ...                ...                         ...   ...
# 28979            DAIRY                         NaN  2016
# 28980            DAIRY                         NaN  2017
# 28981            DAIRY                         NaN  2018
# 28982            DAIRY                         NaN  2019
# 28983            DAIRY                         NaN  2020
#
#        Apparent use (THOUSAND TONS)  Apparent use (THOUSAND TONS (C.W.E.))  \
# 0                        139.610841                                    NaN
# 1                        146.427460                                    NaN
# 2                        140.327465                                    NaN
# 3                        148.229900                                    NaN
# 4                        163.499156                                    NaN
# ...                             ...                                    ...
# 28979                    204.742759                                    NaN
# 28980                    202.162743                                    NaN
# 28981                    202.317560                                    NaN
# 28982                    200.819827                                    NaN
# 28983                    204.460127                                    NaN
#
#        Apparent use (THOUSAND HECTOLITRES)  ...  Population (THOUSAND HEAD)  \
# 0                                      NaN  ...                         NaN
# 1                                      NaN  ...                         NaN
# 2                                      NaN  ...                         NaN
# 3                                      NaN  ...                         NaN
# 4                                      NaN  ...                         NaN
# ...                                    ...  ...                         ...
# 28979                                  NaN  ...                         NaN
# 28980                                  NaN  ...                         NaN
# 28981                                  NaN  ...                         NaN
# 28982                                  NaN  ...                         NaN
# 28983                                  NaN  ...                         NaN
#
#        Production (THOUSAND TONS)  Production (THOUSAND HECTOLITRES)  \
# 0                          190.69                                NaN
# 1                          209.20                                NaN
# 2                          216.10                                NaN
# 3                          235.28                                NaN
# 4                          264.78                                NaN
# ...                           ...                                ...
# 28979                       87.25                                NaN
# 28980                       82.70                                NaN
# 28981                       81.84                                NaN
# 28982                       81.70                                NaN
# 28983                       83.48                                NaN
#
#        Production of primary product (THOUSAND TONS)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 28979                                            NaN
# 28980                                            NaN
# 28981                                            NaN
# 28982                                            NaN
# 28983                                            NaN
#
#        Production (from dairy cows) (THOUSAND TONS)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 28979                                           NaN
# 28980                                           NaN
# 28981                                           NaN
# 28982                                           NaN
# 28983                                           NaN
#
#        Yield (animals) (KG/HEAD)  Yield (crops) (TONNE/HA)  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 28979                        NaN                       NaN
# 28980                        NaN                       NaN
# 28981                        NaN                       NaN
# 28982                        NaN                       NaN
# 28983                        NaN                       NaN
#
#        Yield of secondary product (KG PER TONNE OF PRIMARY PRODUCT)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 28979                                                NaN
# 28980                                                NaN
# 28981                                                NaN
# 28982                                                NaN
# 28983                                                NaN
#
#        Yield (HECTOLITRES PER HECTARE)  Yield of primary product (TONNE/HA)
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
# ...                                ...                                  ...
# 28979                              NaN                                  NaN
# 28980                              NaN                                  NaN
# 28981                              NaN                                  NaN
# 28982                              NaN                                  NaN
# 28983                              NaN                                  NaN
#
# [4104 rows x 46 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})
sns.barplot(x='Production (THOUSAND TONS)',y='Country',data=df);

# %% [markdown]
# To fairly compare the 27 EU countries it will be considered the Farm Structure of each country.
# Using the European Comparison Table provided by where it can be founded details about holdings and agricultural area size in the EU Member States.
#
# Unsupervised Machine Learning Models will be applied in order to cluster the Countries based on their Farm Structure.
#
# For this exercise Hierarchical Cluster and KMeans are the selected models once both works based on Euclidean Distance.

# %%
# Using Pandas to read the dataset.
df1 = pd.read_csv("data/European Comparison-Farm Structure Survey 2013.csv")
# Using head() to visualize the top 5 rows
df1.head(5)
# Out:
#            Country Number of holdings (000)  \
# 0               EU                10,841.00
# 1          Belgium                     37.8
# 2         Bulgaria                    254.4
# 3  Czech Republic                      26.3
# 4         Denmark                      38.8
#
#   Utilised agricultural area (000 hectares)  \
# 0                                174,606.60
# 1                                  1,307.90
# 2                                  4,650.90
# 3                                  3,491.50
# 4                                  2,619.30
#
#    Average area per holding (hectares)
# 0                                 16.1
# 1                                 34.6
# 2                                 18.3
# 3                                133.0
# 4                                 67.5

# %%
# Removing EU row
df1=df1[df1['Country']!="EU"]

# %%
# Replace comma using a Lambda function
df1['Number of holdings (000)'] = df1['Number of holdings (000)'].apply(lambda field: field.replace(",", ""))

# %%
# Replace comma using a Lambda function
df1['Utilised agricultural area (000 hectares)'] = df1['Utilised agricultural area (000 hectares)'].apply(lambda field: field.replace(",", ""))

# %%
# Reset the index after remove EU row.
df1.reset_index(inplace=True, drop=True)
df1
# Out:
#             Country Number of holdings (000)  \
# 0           Belgium                     37.8
# 1          Bulgaria                    254.4
# 2   Czech Republic                      26.3
# 3          Denmark                      38.8
# 4           Germany                      285
# 5          Estonia                      19.2
# 6           Ireland                    139.6
# 7            Greece                    709.5
# 8             Spain                      965
# 9            France                    472.2
# 10         Croatia                     157.4
# 11           Italy                   1010.30
# 12           Cyprus                     35.4
# 13           Latvia                     81.8
# 14        Lithuania                    171.8
# 15      Luxembourg                       2.1
# 16         Hungary                     491.3
# 17           Malta                       9.4
# 18     Netherlands                      67.5
# 19          Austria                    140.4
# 20           Poland                  1429.00
# 21         Portugal                    264.4
# 22          Romania                  3629.70
# 23         Slovenia                     72.4
# 24         Slovakia                     23.6
# 25          Finland                     54.4
# 26           Sweden                     67.1
# 27           Norway                     43.7
#
#    Utilised agricultural area (000 hectares)  \
# 0                                    1307.90
# 1                                    4650.90
# 2                                    3491.50
# 3                                    2619.30
# 4                                   16699.60
# 5                                      957.5
# 6                                    4959.40
# 7                                    4856.80
# 8                                   23300.20
# 9                                   27739.40
# 10                                   1571.20
# 11                                  12098.90
# 12                                     109.3
# 13                                   1877.70
# 14                                   2861.30
# 15                                       131
# 16                                   4656.50
# 17                                      10.9
# 18                                   1847.60
# 19                                   2726.90
# 20                                  14409.90
# 21                                   3641.60
# 22                                  13055.90
# 23                                     485.8
# 24                                   1901.60
# 25                                   2284.40
# 26                                   3028.60
# 27                                     987.1
#
#     Average area per holding (hectares)
# 0                                  34.6
# 1                                  18.3
# 2                                 133.0
# 3                                  67.5
# 4                                  58.6
# 5                                  49.9
# 6                                  35.5
# 7                                   6.8
# 8                                  24.1
# 9                                  58.7
# 10                                 10.0
# 11                                 12.0
# 12                                  3.1
# 13                                 23.0
# 14                                 16.7
# 15                                 63.0
# 16                                  9.5
# 17                                  1.2
# 18                                 27.4
# 19                                 19.4
# 20                                 10.1
# 21                                 13.8
# 22                                  3.6
# 23                                  6.7
# 24                                 80.7
# 25                                 42.0
# 26                                 45.1
# 27                                 22.6

# %%
# Selecting numerical features to applie cluster
df2 = df1[["Average area per holding (hectares)","Utilised agricultural area (000 hectares)","Number of holdings (000)"]]

# %%
# Checking Type of each variables
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 3 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Average area per holding (hectares)        28 non-null     float64
#  1   Utilised agricultural area (000 hectares)  28 non-null     object
#  2   Number of holdings (000)                   28 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 800.0+ bytes

# %%
# Changing objects into float type
df2['Number of holdings (000)'] = df2['Number of holdings (000)'].astype(float)
df2['Utilised agricultural area (000 hectares)'] = df2['Utilised agricultural area (000 hectares)'].astype(float)

# %% [markdown]
# Explain Why use Standard Scaler

# %%
# Use StandardScaler from Scikit Learn to standardize the features onto unit scale (mean = 0 and standard deviation = 1) 
from sklearn.preprocessing import StandardScaler
data_scaled = StandardScaler().fit_transform(df2)

# %%
# array of data set df2 after StandardScaler
data_scaled
# Out:
# array([[ 0.08821495, -0.61621009, -0.48032198],
#        [-0.47174753, -0.14205543, -0.17817215],
#        [ 3.46860191, -0.30649902, -0.4963641 ],
#        [ 1.21844595, -0.43020757, -0.47892702],
#        [ 0.91269957,  1.56687286, -0.13548616],
#        [ 0.61382389, -0.6659091 , -0.50626837],
#        [ 0.11913312, -0.09829931, -0.33831435],
#        [-0.86681308, -0.11285159,  0.4566773 ],
#        [-0.27249708,  2.50306947,  0.81309134],
#        [ 0.91613492,  3.13270375,  0.12565165],
#        [-0.75688179, -0.57886491, -0.31348394],
#        [-0.68817474,  0.91433223,  0.87628335],
#        [-0.99392112, -0.78621361, -0.48366991],
#        [-0.31028595, -0.53539246, -0.41894344],
#        [-0.52671317, -0.39588348, -0.29339642],
#        [ 1.06385509, -0.78313579, -0.5301223 ],
#        [-0.77405856, -0.14126115,  0.15229551],
#        [-1.05919282, -0.80017019, -0.51993905],
#        [-0.15913044, -0.5396617 , -0.43889147],
#        [-0.43395865, -0.41494612, -0.33719838],
#        [-0.75344644,  1.24211309,  1.46035599],
#        [-0.62633839, -0.28520957, -0.16422248],
#        [-0.97674436,  1.05006839,  4.5302597 ],
#        [-0.87024843, -0.73281271, -0.43205613],
#        [ 1.6719125 , -0.53200261, -0.50013052],
#        [ 0.34243104, -0.47770814, -0.45716553],
#        [ 0.44892697, -0.37215447, -0.43944945],
#        [-0.32402736, -0.66171078, -0.47209168]])

# %%
# Using hierarchy to cluster the observations
#importing the library
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
#recovering matplotlib defalts
#plt.rcParams.update(plt.rcParamsDefault)

#Importing scipy.cluster.hierarchy to create dendrogram
import scipy.cluster.hierarchy as sch

dendrogram =sch.dendrogram(sch.linkage(
                data_scaled,method = 'ward'))

#creating the plot, assigning labels and title
plt.title('Dendrogram')
plt.xlabel('Country')
plt.ylabel('Euclidean distances')

# Add horizontal line to visualize .
plt.axhline(y=0.068, c='red', lw=1, linestyle='dashed')
plt.axhline(y=0.05, c='grey', lw=1, linestyle='dashed')

plt.show()

# %%
# Including Cluster Labels
# importing the library 
from sklearn.cluster import AgglomerativeClustering
hierarchy_cluster = AgglomerativeClustering(n_clusters=2, affinity="euclidean", linkage="ward")
#create a pandas series to be used latter on
y1 = pd.Series(hierarchy_cluster.fit_predict(data_scaled), name="Cluster Hierarquical")

# %%
# Plotting Elbow method
import matplotlib.pyplot as plt
#recovering matplotlib defaults
#plt.rcParams.update(plt.rcParamsDefault)

#Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 0)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11),wcss,marker='o')
plt.title('The Elbow Method')
plt.annotate('Possible number of Clusters', xy=(6, 14), xytext=(5.4, 60), arrowprops=dict(facecolor='green'))
plt.annotate("",xy=(4, 23), xytext=(5.2, 59), arrowprops=dict(facecolor='green'))
plt.annotate("",xy=(5, 17), xytext=(5.3, 59), arrowprops=dict(facecolor='green'))
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#Importing and Fitting K-Means to dataset
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 6, init = 'k-means++', random_state = 0)
y2 = pd.Series(kmeans.fit_predict(data_scaled), name="Cluster KMeans")

# %% [markdown]
# Silhouette Coefficient also know as silhouette score is a metric used to calculate the efficiency of a clustering technique.
#
# Its value ranges from -1 to 1.
#
# 1: Means clusters are well apart from each other and clearly distinguished.
#
# 0: Means clusters are indifferent, or we can say that the distance between clusters is not significant.
#
# -1: Means clusters are assigned in the wrong way.

# %%
#importing the library
from sklearn.metrics import silhouette_score

# Calculate Silhouette Score hierarchy
hierarchy_score = silhouette_score(data_scaled, hierarchy_cluster.labels_, metric='euclidean')
# Print the score
print('Silhouette Score Hierarchy for 2 clusters: %.3f' % hierarchy_score)


# Calculate Silhouette Score kmeans
score = silhouette_score(data_scaled, kmeans.labels_, metric='euclidean')
#print('Silhouetter Score for x clusters : %.3f' % score)

# Print the score
print('Silhouette Score KMeans for 4 clusters : 0.486')
print('Silhouette Score KMeans for 5 clusters : 0.479')
print('Silhouette Score KMeans for 6 clusters : 0.438')
# Out:
# Silhouette Score Hierarchy for 2 clusters: 0.533
# Silhouette Score KMeans for 4 clusters : 0.486
# Silhouette Score KMeans for 5 clusters : 0.479
# Silhouette Score KMeans for 6 clusters : 0.438

# %% [markdown]
# The Silhouette Score test suggests Hierarchy with 2 Cluster as the best option with a higher score

# %%
#assigning the Hierarchy cluster labels for each observation in df2
df2 = pd.concat([df1, y1], axis = 1)
df2
# Out:
#             Country Number of holdings (000)  \
# 0           Belgium                     37.8
# 1          Bulgaria                    254.4
# 2   Czech Republic                      26.3
# 3          Denmark                      38.8
# 4           Germany                      285
# 5          Estonia                      19.2
# 6           Ireland                    139.6
# 7            Greece                    709.5
# 8             Spain                      965
# 9            France                    472.2
# 10         Croatia                     157.4
# 11           Italy                   1010.30
# 12           Cyprus                     35.4
# 13           Latvia                     81.8
# 14        Lithuania                    171.8
# 15      Luxembourg                       2.1
# 16         Hungary                     491.3
# 17           Malta                       9.4
# 18     Netherlands                      67.5
# 19          Austria                    140.4
# 20           Poland                  1429.00
# 21         Portugal                    264.4
# 22          Romania                  3629.70
# 23         Slovenia                     72.4
# 24         Slovakia                     23.6
# 25          Finland                     54.4
# 26           Sweden                     67.1
# 27           Norway                     43.7
#
#    Utilised agricultural area (000 hectares)  \
# 0                                    1307.90
# 1                                    4650.90
# 2                                    3491.50
# 3                                    2619.30
# 4                                   16699.60
# 5                                      957.5
# 6                                    4959.40
# 7                                    4856.80
# 8                                   23300.20
# 9                                   27739.40
# 10                                   1571.20
# 11                                  12098.90
# 12                                     109.3
# 13                                   1877.70
# 14                                   2861.30
# 15                                       131
# 16                                   4656.50
# 17                                      10.9
# 18                                   1847.60
# 19                                   2726.90
# 20                                  14409.90
# 21                                   3641.60
# 22                                  13055.90
# 23                                     485.8
# 24                                   1901.60
# 25                                   2284.40
# 26                                   3028.60
# 27                                     987.1
#
#     Average area per holding (hectares)  Cluster Hierarquical
# 0                                  34.6                     0
# 1                                  18.3                     0
# 2                                 133.0                     0
# 3                                  67.5                     0
# 4                                  58.6                     1
# 5                                  49.9                     0
# 6                                  35.5                     0
# 7                                   6.8                     0
# 8                                  24.1                     1
# 9                                  58.7                     1
# 10                                 10.0                     0
# 11                                 12.0                     1
# 12                                  3.1                     0
# 13                                 23.0                     0
# 14                                 16.7                     0
# 15                                 63.0                     0
# 16                                  9.5                     0
# 17                                  1.2                     0
# 18                                 27.4                     0
# 19                                 19.4                     0
# 20                                 10.1                     1
# 21                                 13.8                     0
# 22                                  3.6                     1
# 23                                  6.7                     0
# 24                                 80.7                     0
# 25                                 42.0                     0
# 26                                 45.1                     0
# 27                                 22.6                     0

# %%
# Merging the two datasets using Country as a key and left as a join 
new_df = pd.merge(df, df2, on="Country", how="left")

# %%
new_df
# Out:
#       Country Country (NUTS Code) Country (Description)       Commodity  \
# 0     Austria                  AT                   NaN  ACIDIFIED MILK
# 1     Austria                  AT                   NaN  ACIDIFIED MILK
# 2     Austria                  AT                   NaN  ACIDIFIED MILK
# 3     Austria                  AT                   NaN  ACIDIFIED MILK
# 4     Austria                  AT                   NaN  ACIDIFIED MILK
# ...       ...                 ...                   ...             ...
# 4099   Sweden                  SE                   NaN    TOTAL CHEESE
# 4100   Sweden                  SE                   NaN    TOTAL CHEESE
# 4101   Sweden                  SE                   NaN    TOTAL CHEESE
# 4102   Sweden                  SE                   NaN    TOTAL CHEESE
# 4103   Sweden                  SE                   NaN    TOTAL CHEESE
#
#      Commodity (Type) Commodity (Primary product)  Year  \
# 0               DAIRY                         NaN  2002
# 1               DAIRY                         NaN  2003
# 2               DAIRY                         NaN  2004
# 3               DAIRY                         NaN  2005
# 4               DAIRY                         NaN  2006
# ...               ...                         ...   ...
# 4099            DAIRY                         NaN  2016
# 4100            DAIRY                         NaN  2017
# 4101            DAIRY                         NaN  2018
# 4102            DAIRY                         NaN  2019
# 4103            DAIRY                         NaN  2020
#
#       Apparent use (THOUSAND TONS)  Apparent use (THOUSAND TONS (C.W.E.))  \
# 0                       139.610841                                    NaN
# 1                       146.427460                                    NaN
# 2                       140.327465                                    NaN
# 3                       148.229900                                    NaN
# 4                       163.499156                                    NaN
# ...                            ...                                    ...
# 4099                    204.742759                                    NaN
# 4100                    202.162743                                    NaN
# 4101                    202.317560                                    NaN
# 4102                    200.819827                                    NaN
# 4103                    204.460127                                    NaN
#
#       Apparent use (THOUSAND HECTOLITRES)  ...  \
# 0                                     NaN  ...
# 1                                     NaN  ...
# 2                                     NaN  ...
# 3                                     NaN  ...
# 4                                     NaN  ...
# ...                                   ...  ...
# 4099                                  NaN  ...
# 4100                                  NaN  ...
# 4101                                  NaN  ...
# 4102                                  NaN  ...
# 4103                                  NaN  ...
#
#       Production (from dairy cows) (THOUSAND TONS)  Yield (animals) (KG/HEAD)  \
# 0                                              NaN                        NaN
# 1                                              NaN                        NaN
# 2                                              NaN                        NaN
# 3                                              NaN                        NaN
# 4                                              NaN                        NaN
# ...                                            ...                        ...
# 4099                                           NaN                        NaN
# 4100                                           NaN                        NaN
# 4101                                           NaN                        NaN
# 4102                                           NaN                        NaN
# 4103                                           NaN                        NaN
#
#       Yield (crops) (TONNE/HA)  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 4099                       NaN
# 4100                       NaN
# 4101                       NaN
# 4102                       NaN
# 4103                       NaN
#
#       Yield of secondary product (KG PER TONNE OF PRIMARY PRODUCT)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4099                                                NaN
# 4100                                                NaN
# 4101                                                NaN
# 4102                                                NaN
# 4103                                                NaN
#
#       Yield (HECTOLITRES PER HECTARE)  Yield of primary product (TONNE/HA)  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# ...                               ...                                  ...
# 4099                              NaN                                  NaN
# 4100                              NaN                                  NaN
# 4101                              NaN                                  NaN
# 4102                              NaN                                  NaN
# 4103                              NaN                                  NaN
#
#       Number of holdings (000)  Utilised agricultural area (000 hectares)  \
# 0                        140.4                                    2726.90
# 1                        140.4                                    2726.90
# 2                        140.4                                    2726.90
# 3                        140.4                                    2726.90
# 4                        140.4                                    2726.90
# ...                        ...                                        ...
# 4099                      67.1                                    3028.60
# 4100                      67.1                                    3028.60
# 4101                      67.1                                    3028.60
# 4102                      67.1                                    3028.60
# 4103                      67.1                                    3028.60
#
#       Average area per holding (hectares)  Cluster Hierarquical
# 0                                    19.4                   0.0
# 1                                    19.4                   0.0
# 2                                    19.4                   0.0
# 3                                    19.4                   0.0
# 4                                    19.4                   0.0
# ...                                   ...                   ...
# 4099                                 45.1                   0.0
# 4100                                 45.1                   0.0
# 4101                                 45.1                   0.0
# 4102                                 45.1                   0.0
# 4103                                 45.1                   0.0
#
# [4104 rows x 50 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4104 entries, 0 to 4103
# Data columns (total 50 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Country                                                       4104 non-null   object
#  1   Country (NUTS Code)                                           4104 non-null   object
#  2   Country (Description)                                         0 non-null      object
#  3   Commodity                                                     4104 non-null   object
#  4   Commodity (Type)                                              4104 non-null   object
#  5   Commodity (Primary product)                                   0 non-null      object
#  6   Year                                                          4104 non-null   int64
#  7   Apparent use (THOUSAND TONS)                                  4104 non-null   float64
#  8   Apparent use (THOUSAND TONS (C.W.E.))                         0 non-null      float64
#  9   Apparent use (THOUSAND HECTOLITRES)                           0 non-null      float64
#  10  Beginning stocks (THOUSAND TONS)                              0 non-null      float64
#  11  Beginning stocks (THOUSAND HECTOLITRES)                       0 non-null      float64
#  12  Carcass weight (KG/HEAD)                                      0 non-null      float64
#  13  Deliveries (THOUSAND TONS)                                    0 non-null      float64
#  14  Ending stocks (THOUSAND TONS)                                 0 non-null      float64
#  15  Ending stocks (THOUSAND HECTOLITRES)                          0 non-null      float64
#  16  Exports (Extra-EU) (THOUSAND TONS)                            4104 non-null   float64
#  17  Exports (Intra-EU) (THOUSAND TONS)                            4104 non-null   float64
#  18  Exports (Extra-EU) (THOUSAND HECTOLITRES)                     0 non-null      float64
#  19  Exports (Intra-EU) (THOUSAND HECTOLITRES)                     0 non-null      float64
#  20  Gross indigenous production (THOUSAND TONS (C.W.E.))          0 non-null      float64
#  21  Harvested area (THOUSAND HECTARES)                            0 non-null      float64
#  22  Imports (Extra-EU) (THOUSAND TONS)                            4104 non-null   float64
#  23  Imports (Intra-EU) (THOUSAND TONS)                            4104 non-null   float64
#  24  Imports (Extra-EU) (THOUSAND HECTOLITRES)                     0 non-null      float64
#  25  Imports (Intra-EU) (THOUSAND HECTOLITRES)                     0 non-null      float64
#  26  Live exports (Extra-EU) (THOUSAND TONS (C.W.E.))              0 non-null      float64
#  27  Live exports (Intra-EU) (THOUSAND TONS (C.W.E.))              0 non-null      float64
#  28  Live imports (Extra-EU) (THOUSAND TONS (C.W.E.))              0 non-null      float64
#  29  Live imports (Intra-EU) (THOUSAND TONS (C.W.E.))              0 non-null      float64
#  30  Meat exports (Extra-EU) (THOUSAND TONS (C.W.E.))              0 non-null      float64
#  31  Meat exports (Intra-EU) (THOUSAND TONS (C.W.E.))              0 non-null      float64
#  32  Meat imports (Extra-EU) (THOUSAND TONS (C.W.E.))              0 non-null      float64
#  33  Meat imports (Intra-EU) (THOUSAND TONS (C.W.E.))              0 non-null      float64
#  34  Net production (heads) (THOUSAND HEAD)                        0 non-null      float64
#  35  Net production (tons) (THOUSAND TONS (C.W.E.))                0 non-null      float64
#  36  Population (THOUSAND HEAD)                                    0 non-null      float64
#  37  Production (THOUSAND TONS)                                    4104 non-null   float64
#  38  Production (THOUSAND HECTOLITRES)                             0 non-null      float64
#  39  Production of primary product (THOUSAND TONS)                 0 non-null      float64
#  40  Production (from dairy cows) (THOUSAND TONS)                  0 non-null      float64
#  41  Yield (animals) (KG/HEAD)                                     0 non-null      float64
#  42  Yield (crops) (TONNE/HA)                                      0 non-null      float64
#  43  Yield of secondary product (KG PER TONNE OF PRIMARY PRODUCT)  0 non-null      float64
#  44  Yield (HECTOLITRES PER HECTARE)                               0 non-null      float64
#  45  Yield of primary product (TONNE/HA)                           0 non-null      float64
#  46  Number of holdings (000)                                      2736 non-null   object
#  47  Utilised agricultural area (000 hectares)                     2736 non-null   object
#  48  Average area per holding (hectares)                           2736 non-null   float64
#  49  Cluster Hierarquical                                          2736 non-null   float64
# dtypes: float64(41), int64(1), object(8)
# memory usage: 1.6+ MB

# %% [markdown]
# As previous seen Ireland belongs to the Cluster 0, for that reason Cluster one will be ignored for next steps.

# %%
# New dataframe with only cluster 0
list_country_1 = new_df[new_df["Cluster Hierarquical"] == 0]
list_country_1
# Out:
#       Country Country (NUTS Code) Country (Description)       Commodity  \
# 0     Austria                  AT                   NaN  ACIDIFIED MILK
# 1     Austria                  AT                   NaN  ACIDIFIED MILK
# 2     Austria                  AT                   NaN  ACIDIFIED MILK
# 3     Austria                  AT                   NaN  ACIDIFIED MILK
# 4     Austria                  AT                   NaN  ACIDIFIED MILK
# ...       ...                 ...                   ...             ...
# 4099   Sweden                  SE                   NaN    TOTAL CHEESE
# 4100   Sweden                  SE                   NaN    TOTAL CHEESE
# 4101   Sweden                  SE                   NaN    TOTAL CHEESE
# 4102   Sweden                  SE                   NaN    TOTAL CHEESE
# 4103   Sweden                  SE                   NaN    TOTAL CHEESE
#
#      Commodity (Type) Commodity (Primary product)  Year  \
# 0               DAIRY                         NaN  2002
# 1               DAIRY                         NaN  2003
# 2               DAIRY                         NaN  2004
# 3               DAIRY                         NaN  2005
# 4               DAIRY                         NaN  2006
# ...               ...                         ...   ...
# 4099            DAIRY                         NaN  2016
# 4100            DAIRY                         NaN  2017
# 4101            DAIRY                         NaN  2018
# 4102            DAIRY                         NaN  2019
# 4103            DAIRY                         NaN  2020
#
#       Apparent use (THOUSAND TONS)  Apparent use (THOUSAND TONS (C.W.E.))  \
# 0                       139.610841                                    NaN
# 1                       146.427460                                    NaN
# 2                       140.327465                                    NaN
# 3                       148.229900                                    NaN
# 4                       163.499156                                    NaN
# ...                            ...                                    ...
# 4099                    204.742759                                    NaN
# 4100                    202.162743                                    NaN
# 4101                    202.317560                                    NaN
# 4102                    200.819827                                    NaN
# 4103                    204.460127                                    NaN
#
#       Apparent use (THOUSAND HECTOLITRES)  ...  \
# 0                                     NaN  ...
# 1                                     NaN  ...
# 2                                     NaN  ...
# 3                                     NaN  ...
# 4                                     NaN  ...
# ...                                   ...  ...
# 4099                                  NaN  ...
# 4100                                  NaN  ...
# 4101                                  NaN  ...
# 4102                                  NaN  ...
# 4103                                  NaN  ...
#
#       Production (from dairy cows) (THOUSAND TONS)  Yield (animals) (KG/HEAD)  \
# 0                                              NaN                        NaN
# 1                                              NaN                        NaN
# 2                                              NaN                        NaN
# 3                                              NaN                        NaN
# 4                                              NaN                        NaN
# ...                                            ...                        ...
# 4099                                           NaN                        NaN
# 4100                                           NaN                        NaN
# 4101                                           NaN                        NaN
# 4102                                           NaN                        NaN
# 4103                                           NaN                        NaN
#
#       Yield (crops) (TONNE/HA)  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 4099                       NaN
# 4100                       NaN
# 4101                       NaN
# 4102                       NaN
# 4103                       NaN
#
#       Yield of secondary product (KG PER TONNE OF PRIMARY PRODUCT)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4099                                                NaN
# 4100                                                NaN
# 4101                                                NaN
# 4102                                                NaN
# 4103                                                NaN
#
#       Yield (HECTOLITRES PER HECTARE)  Yield of primary product (TONNE/HA)  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# ...                               ...                                  ...
# 4099                              NaN                                  NaN
# 4100                              NaN                                  NaN
# 4101                              NaN                                  NaN
# 4102                              NaN                                  NaN
# 4103                              NaN                                  NaN
#
#       Number of holdings (000)  Utilised agricultural area (000 hectares)  \
# 0                        140.4                                    2726.90
# 1                        140.4                                    2726.90
# 2                        140.4                                    2726.90
# 3                        140.4                                    2726.90
# 4                        140.4                                    2726.90
# ...                        ...                                        ...
# 4099                      67.1                                    3028.60
# 4100                      67.1                                    3028.60
# 4101                      67.1                                    3028.60
# 4102                      67.1                                    3028.60
# 4103                      67.1                                    3028.60
#
#       Average area per holding (hectares)  Cluster Hierarquical
# 0                                    19.4                   0.0
# 1                                    19.4                   0.0
# 2                                    19.4                   0.0
# 3                                    19.4                   0.0
# 4                                    19.4                   0.0
# ...                                   ...                   ...
# 4099                                 45.1                   0.0
# 4100                                 45.1                   0.0
# 4101                                 45.1                   0.0
# 4102                                 45.1                   0.0
# 4103                                 45.1                   0.0
#
# [1976 rows x 50 columns]

# %% [markdown]
# Selecting interested columns

# %%
list_country_1=list_country_1.loc[:,['Year','Country','Commodity','Apparent use (THOUSAND TONS)','Production (THOUSAND TONS)','Exports (Extra-EU) (THOUSAND TONS)','Exports (Intra-EU) (THOUSAND TONS)','Imports (Extra-EU) (THOUSAND TONS)','Imports (Intra-EU) (THOUSAND TONS)']]

# %%
df= list_country_1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(7,5), 'figure.dpi':100})
sns.barplot(x='Production (THOUSAND TONS)',y='Country',data=df);

# %%
# Data Type of each variable.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1976 entries, 0 to 4103
# Data columns (total 9 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Year                                1976 non-null   int64
#  1   Country                             1976 non-null   object
#  2   Commodity                           1976 non-null   object
#  3   Apparent use (THOUSAND TONS)        1976 non-null   float64
#  4   Production (THOUSAND TONS)          1976 non-null   float64
#  5   Exports (Extra-EU) (THOUSAND TONS)  1976 non-null   float64
#  6   Exports (Intra-EU) (THOUSAND TONS)  1976 non-null   float64
#  7   Imports (Extra-EU) (THOUSAND TONS)  1976 non-null   float64
#  8   Imports (Intra-EU) (THOUSAND TONS)  1976 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 234.4+ KB

# %% [markdown]
# ***Central Tendency Measures***
#
# These measures will allow us to summarize in a single number all the values reflecting the centre of the data distribution
#
# ***Variation Measures***
#
# These measures help us to get values that determine the level of homogeneity within the observations.
#
# In other words, we can see how different/similar the values are.

# %%
# df.describe is a way to summarize the data using Descriptive Statistics: 
#Central Tendency and Measures of variability for Numerical features (except Station ID and Latitude and Longitue)
# I am Using .round() to suppress scientific notation.
df.describe(include=['int64','float64']).round()
# Out:
#          Year  Apparent use (THOUSAND TONS)  Production (THOUSAND TONS)  \
# count  1976.0                        1976.0                      1976.0
# mean   2011.0                         163.0                       175.0
# std       5.0                         296.0                       293.0
# min    2002.0                        -185.0                         0.0
# 25%    2006.0                          10.0                        13.0
# 50%    2011.0                          37.0                        56.0
# 75%    2016.0                         163.0                       183.0
# max    2020.0                        1860.0                      1612.0
#
#        Exports (Extra-EU) (THOUSAND TONS)  Exports (Intra-EU) (THOUSAND TONS)  \
# count                              1976.0                              1976.0
# mean                                 12.0                                63.0
# std                                  30.0                               163.0
# min                                   0.0                                 0.0
# 25%                                   0.0                                 1.0
# 50%                                   2.0                                 6.0
# 75%                                   9.0                                40.0
# max                                 242.0                              1166.0
#
#        Imports (Extra-EU) (THOUSAND TONS)  Imports (Intra-EU) (THOUSAND TONS)
# count                              1976.0                              1976.0
# mean                                 10.0                                54.0
# std                                  63.0                               139.0
# min                                   0.0                                 0.0
# 25%                                   0.0                                 2.0
# 50%                                   0.0                                10.0
# 75%                                   0.0                                49.0
# max                                 795.0                              1476.0

# %%
# Using df.describe to get summary statistics for objects
df.describe(include=np.object)
# Out:
#        Country       Commodity
# count     1976            1976
# unique      13               8
# top     Sweden  ACIDIFIED MILK
# freq       152             247

# %%
# Using EDA Dataprep to create a full report about the Dataset.
# As this can take longer and require some libraries being installed the report will be also supplied as HTLM and PDF to facilitate.
# To create the report please re-run the below line removing the #

# %%
#create_report(df).show()

# %%
df
# Out:
#       Year  Country       Commodity  Apparent use (THOUSAND TONS)  \
# 0     2002  Austria  ACIDIFIED MILK                    139.610841
# 1     2003  Austria  ACIDIFIED MILK                    146.427460
# 2     2004  Austria  ACIDIFIED MILK                    140.327465
# 3     2005  Austria  ACIDIFIED MILK                    148.229900
# 4     2006  Austria  ACIDIFIED MILK                    163.499156
# ...    ...      ...             ...                           ...
# 4099  2016   Sweden    TOTAL CHEESE                    204.742759
# 4100  2017   Sweden    TOTAL CHEESE                    202.162743
# 4101  2018   Sweden    TOTAL CHEESE                    202.317560
# 4102  2019   Sweden    TOTAL CHEESE                    200.819827
# 4103  2020   Sweden    TOTAL CHEESE                    204.460127
#
#       Production (THOUSAND TONS)  Exports (Extra-EU) (THOUSAND TONS)  \
# 0                         190.69                            0.467400
# 1                         209.20                            0.784900
# 2                         216.10                            1.643100
# 3                         235.28                            1.552800
# 4                         264.78                            6.184200
# ...                          ...                                 ...
# 4099                       87.25                            1.866894
# 4100                       82.70                            1.698250
# 4101                       81.84                            1.491119
# 4102                       81.70                            1.347509
# 4103                       83.48                            1.389547
#
#       Exports (Intra-EU) (THOUSAND TONS)  Imports (Extra-EU) (THOUSAND TONS)  \
# 0                              64.847200                            0.076800
# 1                              81.618900                            0.029800
# 2                              94.539300                            0.008100
# 3                             105.245400                            0.028700
# 4                             119.379200                            0.028300
# ...                                  ...                                 ...
# 4099                           14.725435                            4.039778
# 4100                           16.593673                            3.264300
# 4101                           16.053974                            2.973341
# 4102                           18.083771                            3.557239
# 4103                           16.339162                            2.923135
#
#       Imports (Intra-EU) (THOUSAND TONS)
# 0                              14.158641
# 1                              19.601460
# 2                              20.401765
# 3                              19.719400
# 4                              24.254256
# ...                                  ...
# 4099                          130.045310
# 4100                          134.490366
# 4101                          135.049312
# 4102                          134.993868
# 4103                          135.785701
#
# [1976 rows x 9 columns]

# %%
data = df.sample(frac=0.9, random_state=786)
data_unseen = df.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (1778, 9)
# Unseen Data For Predictions: (198, 9)

# %%
from pycaret.classification import *
exp_mclf101 = setup(data = data, target = 'Country', session_id=123)
# Out:
# <style  type="text/css" >
# </style><table id="T_3605691e_c948_11ec_a180_f3e8809ff066" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row1_col1" class="data row1 col1" >Country</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row2_col1" class="data row2 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row3_col1" class="data row3 col1" >Austria: 0, Belgium: 1, Bulgaria: 2, Cyprus: 3, Finland: 4, Greece: 5, Ireland: 6, Latvia: 7, Lithuania: 8, Portugal: 9, Slovakia: 10, Slovenia: 11, Sweden: 12</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row4_col1" class="data row4 col1" >(1778, 9)</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row6_col1" class="data row6 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row7_col1" class="data row7 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row11_col1" class="data row11 col1" >(1244, 33)</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row12_col1" class="data row12 col1" >(534, 33)</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_3605691e_c948_11ec_a180_f3e8809ff066level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_3605691e_c948_11ec_a180_f3e8809ff066row18_col0" class="data row18 col0" >Use GPU</td>

# %%
best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_a3151152_c948_11ec_a003_f3e8809ff066 th {
#           text-align: left;
#     }#T_a3151152_c948_11ec_a003_f3e8809ff066row0_col0,#T_a3151152_c948_11ec_a003_f3e8809ff066row1_col0,#T_a3151152_c948_11ec_a003_f3e8809ff066row1_col1,#T_a3151152_c948_11ec_a003_f3e8809ff066row1_col2,#T_a3151152_c948_11ec_a003_f3e8809ff066row1_col3,#T_a3151152_c948_11ec_a003_f3e8809ff066row1_col4,#T_a3151152_c948_11ec_a003_f3e8809ff066row1_col5,#T_a3151152_c948_11ec_a003_f3e8809ff066row1_col6,#T_a3151152_c948_11ec_a003_f3e8809ff066row1_col7,#T_a3151152_c948_11ec_a003_f3e8809ff066row2_col0,#T_a3151152_c948_11ec_a003_f3e8809ff066row2_col1,#T_a3151152_c948_11ec_a003_f3e8809ff066row2_col2,#T_a3151152_c948_11ec_a003_f3e8809ff066row2_col3,#T_a3151152_c948_11ec_a003_f3e8809ff066row2_col4,#T_a3151152_c948_11ec_a003_f3e8809ff066row2_col5,#T_a3151152_c948_11ec_a003_f3e8809ff066row2_col6,#T_a3151152_c948_11ec_a003_f3e8809ff066row2_col7,#T_a3151152_c948_11ec_a003_f3e8809ff066row3_col0,#T_a3151152_c948_11ec_a003_f3e8809ff066row3_col1,#T_a3151152_c948_11ec_a003_f3e8809ff066row3_col2,#T_a3151152_c948_11ec_a003_f3e8809ff066row3_col3,#T_a3151152_c948_11ec_a003_f3e8809ff066row3_col4,#T_a3151152_c948_11ec_a003_f3e8809ff066row3_col5,#T_a3151152_c948_11ec_a003_f3e8809ff066row3_col6,#T_a3151152_c948_11ec_a003_f3e8809ff066row3_col7,#T_a3151152_c948_11ec_a003_f3e8809ff066row4_col0,#T_a3151152_c948_11ec_a003_f3e8809ff066row4_col1,#T_a3151152_c948_11ec_a003_f3e8809ff066row4_col2,#T_a3151152_c948_11ec_a003_f3e8809ff066row4_col3,#T_a3151152_c948_11ec_a003_f3e8809ff066row4_col4,#T_a3151152_c948_11ec_a003_f3e8809ff066row4_col5,#T_a3151152_c948_11ec_a003_f3e8809ff066row4_col6,#T_a3151152_c948_11ec_a003_f3e8809ff066row4_col7,#T_a3151152_c948_11ec_a003_f3e8809ff066row5_col0,#T_a3151152_c948_11ec_a003_f3e8809ff066row5_col1,#T_a3151152_c948_11ec_a003_f3e8809ff066row5_col2,#T_a3151152_c948_11ec_a003_f3e8809ff066row5_col3,#T_a3151152_c948_11ec_a003_f3e8809ff066row5_col4,#T_a3151152_c948_11ec_a003_f3e8809ff066row5_col5,#T_a3151152_c948_11ec_a003_f3e8809ff066row5_col6,#T_a3151152_c948_11ec_a003_f3e8809ff066row5_col7,#T_a3151152_c948_11ec_a003_f3e8809ff066row6_col0,#T_a3151152_c948_11ec_a003_f3e8809ff066row6_col1,#T_a3151152_c948_11ec_a003_f3e8809ff066row6_col2,#T_a3151152_c948_11ec_a003_f3e8809ff066row6_col3,#T_a3151152_c948_11ec_a003_f3e8809ff066row6_col4,#T_a3151152_c948_11ec_a003_f3e8809ff066row6_col5,#T_a3151152_c948_11ec_a003_f3e8809ff066row6_col6,#T_a3151152_c948_11ec_a003_f3e8809ff066row6_col7,#T_a3151152_c948_11ec_a003_f3e8809ff066row7_col0,#T_a3151152_c948_11ec_a003_f3e8809ff066row7_col1,#T_a3151152_c948_11ec_a003_f3e8809ff066row7_col2,#T_a3151152_c948_11ec_a003_f3e8809ff066row7_col3,#T_a3151152_c948_11ec_a003_f3e8809ff066row7_col4,#T_a3151152_c948_11ec_a003_f3e8809ff066row7_col5,#T_a3151152_c948_11ec_a003_f3e8809ff066row7_col6,#T_a3151152_c948_11ec_a003_f3e8809ff066row7_col7,#T_a3151152_c948_11ec_a003_f3e8809ff066row8_col0,#T_a3151152_c948_11ec_a003_f3e8809ff066row8_col1,#T_a3151152_c948_11ec_a003_f3e8809ff066row8_col2,#T_a3151152_c948_11ec_a003_f3e8809ff066row8_col3,#T_a3151152_c948_11ec_a003_f3e8809ff066row8_col4,#T_a3151152_c948_11ec_a003_f3e8809ff066row8_col5,#T_a3151152_c948_11ec_a003_f3e8809ff066row8_col6,#T_a3151152_c948_11ec_a003_f3e8809ff066row8_col7,#T_a3151152_c948_11ec_a003_f3e8809ff066row9_col0,#T_a3151152_c948_11ec_a003_f3e8809ff066row9_col1,#T_a3151152_c948_11ec_a003_f3e8809ff066row9_col2,#T_a3151152_c948_11ec_a003_f3e8809ff066row9_col3,#T_a3151152_c948_11ec_a003_f3e8809ff066row9_col4,#T_a3151152_c948_11ec_a003_f3e8809ff066row9_col5,#T_a3151152_c948_11ec_a003_f3e8809ff066row9_col6,#T_a3151152_c948_11ec_a003_f3e8809ff066row9_col7,#T_a3151152_c948_11ec_a003_f3e8809ff066row10_col0,#T_a3151152_c948_11ec_a003_f3e8809ff066row10_col1,#T_a3151152_c948_11ec_a003_f3e8809ff066row10_col2,#T_a3151152_c948_11ec_a003_f3e8809ff066row10_col3,#T_a3151152_c948_11ec_a003_f3e8809ff066row10_col4,#T_a3151152_c948_11ec_a003_f3e8809ff066row10_col5,#T_a3151152_c948_11ec_a003_f3e8809ff066row10_col6,#T_a3151152_c948_11ec_a003_f3e8809ff066row10_col7,#T_a3151152_c948_1 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_a3151152_c948_11ec_a003_f3e8809ff066row0_col1,#T_a3151152_c948_11ec_a003_f3e8809ff066row0_col2,#T_a3151152_c948_11ec_a003_f3e8809ff066row0_col3,#T_a3151152_c948_11ec_a003_f3e8809ff066row0_col4,#T_a3151152_c948_11ec_a003_f3e8809ff066row0_col5,#T_a3151152_c948_11ec_a003_f3e8809ff066row0_col6,#T_a3151152_c948_11ec_a003_f3e8809ff066row0_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_a3151152_c948_11ec_a003_f3e8809ff066row0_col8,#T_a3151152_c948_11ec_a003_f3e8809ff066row1_col8,#T_a3151152_c948_11ec_a003_f3e8809ff066row2_col8,#T_a3151152_c948_11ec_a003_f3e8809ff066row3_col8,#T_a3151152_c948_11ec_a003_f3e8809ff066row4_col8,#T_a3151152_c948_11ec_a003_f3e8809ff066row5_col8,#T_a3151152_c948_11ec_a003_f3e8809ff066row6_col8,#T_a3151152_c948_11ec_a003_f3e8809ff066row7_col8,#T_a3151152_c948_11ec_a003_f3e8809ff066row8_col8,#T_a3151152_c948_11ec_a003_f3e8809ff066row9_col8,#T_a3151152_c948_11ec_a003_f3e8809ff066row10_col8,#T_a3151152_c948_11ec_a003_f3e8809ff066row11_col8,#T_a3151152_c948_11ec_a003_f3e8809ff066row12_col8,#T_a3151152_c948_11ec_a003_f3e8809ff066row14_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_a3151152_c948_11ec_a003_f3e8809ff066row13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_a3151152_c948_11ec_a003_f3e8809ff066" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a3151152_c948_11ec_a003_f3e8809ff066level0_row0" class="row_heading level0 row0" >catboost</t

# %%
rf = create_model('rf')
# Out:
# <style  type="text/css" >
# #T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row10_col0,#T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row10_col1,#T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row10_col2,#T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row10_col3,#T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row10_col4,#T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row10_col5,#T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row10_col6{
#             background:  yellow;
#         }</style><table id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row0_col0" class="data row0 col0" >0.9280</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row0_col1" class="data row0 col1" >0.9947</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row0_col2" class="data row0 col2" >0.9274</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row0_col3" class="data row0 col3" >0.9368</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row0_col4" class="data row0 col4" >0.9274</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row0_col5" class="data row0 col5" >0.9220</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row0_col6" class="data row0 col6" >0.9227</td>
#             </tr>
#             <tr>
#                         <th id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row1_col0" class="data row1 col0" >0.8960</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row1_col1" class="data row1 col1" >0.9941</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row1_col2" class="data row1 col2" >0.8949</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row1_col3" class="data row1 col3" >0.9060</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row1_col4" class="data row1 col4" >0.8936</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row1_col5" class="data row1 col5" >0.8873</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row1_col6" class="data row1 col6" >0.8884</td>
#             </tr>
#             <tr>
#                         <th id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row2_col0" class="data row2 col0" >0.9680</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row2_col1" class="data row2 col1" >0.9954</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row2_col2" class="data row2 col2" >0.9684</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row2_col3" class="data row2 col3" >0.9694</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row2_col4" class="data row2 col4" >0.9675</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row2_col5" class="data row2 col5" >0.9653</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row2_col6" class="data row2 col6" >0.9655</td>
#             </tr>
#             <tr>
#                         <th id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row3_col0" class="data row3 col0" >0.9120</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row3_col1" class="data row3 col1" >0.9952</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row3_col2" class="data row3 col2" >0.9110</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row3_col3" class="data row3 col3" >0.9144</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row3_col4" class="data row3 col4" >0.9101</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row3_col5" class="data row3 col5" >0.9046</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row3_col6" class="data row3 col6" >0.9052</td>
#             </tr>
#             <tr>
#                         <th id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row4_col0" class="data row4 col0" >0.9194</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row4_col1" class="data row4 col1" >0.9912</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row4_col2" class="data row4 col2" >0.9212</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row4_col3" class="data row4 col3" >0.9249</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row4_col4" class="data row4 col4" >0.9179</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row4_col5" class="data row4 col5" >0.9126</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row4_col6" class="data row4 col6" >0.9133</td>
#             </tr>
#             <tr>
#                         <th id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row5_col0" class="data row5 col0" >0.9274</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row5_col1" class="data row5 col1" >0.9977</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row5_col2" class="data row5 col2" >0.9288</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row5_col3" class="data row5 col3" >0.9320</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row5_col4" class="data row5 col4" >0.9262</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row5_col5" class="data row5 col5" >0.9214</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row5_col6" class="data row5 col6" >0.9219</td>
#             </tr>
#             <tr>
#                         <th id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row6_col0" class="data row6 col0" >0.8871</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row6_col1" class="data row6 col1" >0.9945</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row6_col2" class="data row6 col2" >0.8880</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row6_col3" class="data row6 col3" >0.8982</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row6_col4" class="data row6 col4" >0.8876</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row6_col5" class="data row6 col5" >0.8777</td>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row6_col6" class="data row6 col6" >0.8785</td>
#             </tr>
#             <tr>
#                         <th id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_a4ec4ac0_c948_11ec_9710_f3e8809ff066row7_co

# %%
#trained model object is stored in the variable 'dt'. 
print(rf)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)

# %%
tuned_rf = tune_model(rf)
# Out:
# <style  type="text/css" >
# #T_b17c24f4_c948_11ec_aa94_f3e8809ff066row10_col0,#T_b17c24f4_c948_11ec_aa94_f3e8809ff066row10_col1,#T_b17c24f4_c948_11ec_aa94_f3e8809ff066row10_col2,#T_b17c24f4_c948_11ec_aa94_f3e8809ff066row10_col3,#T_b17c24f4_c948_11ec_aa94_f3e8809ff066row10_col4,#T_b17c24f4_c948_11ec_aa94_f3e8809ff066row10_col5,#T_b17c24f4_c948_11ec_aa94_f3e8809ff066row10_col6{
#             background:  yellow;
#         }</style><table id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row0_col0" class="data row0 col0" >0.5760</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row0_col1" class="data row0 col1" >0.9301</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row0_col2" class="data row0 col2" >0.5778</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row0_col3" class="data row0 col3" >0.6475</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row0_col4" class="data row0 col4" >0.5753</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row0_col5" class="data row0 col5" >0.5403</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row0_col6" class="data row0 col6" >0.5448</td>
#             </tr>
#             <tr>
#                         <th id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row1_col0" class="data row1 col0" >0.5840</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row1_col1" class="data row1 col1" >0.9315</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row1_col2" class="data row1 col2" >0.5895</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row1_col3" class="data row1 col3" >0.6761</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row1_col4" class="data row1 col4" >0.5802</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row1_col5" class="data row1 col5" >0.5492</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row1_col6" class="data row1 col6" >0.5567</td>
#             </tr>
#             <tr>
#                         <th id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row2_col0" class="data row2 col0" >0.7920</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row2_col1" class="data row2 col1" >0.9667</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row2_col2" class="data row2 col2" >0.7911</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row2_col3" class="data row2 col3" >0.8127</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row2_col4" class="data row2 col4" >0.7920</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row2_col5" class="data row2 col5" >0.7746</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row2_col6" class="data row2 col6" >0.7761</td>
#             </tr>
#             <tr>
#                         <th id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row3_col0" class="data row3 col0" >0.6320</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row3_col1" class="data row3 col1" >0.9406</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row3_col2" class="data row3 col2" >0.6303</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row3_col3" class="data row3 col3" >0.6894</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row3_col4" class="data row3 col4" >0.6364</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row3_col5" class="data row3 col5" >0.6012</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row3_col6" class="data row3 col6" >0.6049</td>
#             </tr>
#             <tr>
#                         <th id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row4_col0" class="data row4 col0" >0.6452</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row4_col1" class="data row4 col1" >0.9509</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row4_col2" class="data row4 col2" >0.6426</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row4_col3" class="data row4 col3" >0.6674</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row4_col4" class="data row4 col4" >0.6235</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row4_col5" class="data row4 col5" >0.6152</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row4_col6" class="data row4 col6" >0.6206</td>
#             </tr>
#             <tr>
#                         <th id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row5_col0" class="data row5 col0" >0.6935</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row5_col1" class="data row5 col1" >0.9579</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row5_col2" class="data row5 col2" >0.7006</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row5_col3" class="data row5 col3" >0.7232</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row5_col4" class="data row5 col4" >0.6881</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row5_col5" class="data row5 col5" >0.6681</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row5_col6" class="data row5 col6" >0.6721</td>
#             </tr>
#             <tr>
#                         <th id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row6_col0" class="data row6 col0" >0.5806</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row6_col1" class="data row6 col1" >0.9428</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row6_col2" class="data row6 col2" >0.5816</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row6_col3" class="data row6 col3" >0.6216</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row6_col4" class="data row6 col4" >0.5741</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row6_col5" class="data row6 col5" >0.5457</td>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row6_col6" class="data row6 col6" >0.5502</td>
#             </tr>
#             <tr>
#                         <th id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_b17c24f4_c948_11ec_aa94_f3e8809ff066row7_co

# %%
#tuned model object is stored in the variable 'tuned_dt'. 
print(tuned_rf)
# Out:
# RandomForestClassifier(bootstrap=False, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=6, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.001,
#                        min_impurity_split=None, min_samples_leaf=6,
#                        min_samples_split=9, min_weight_fraction_leaf=0.0,
#                        n_estimators=190, n_jobs=-1, oob_score=False,
#                        random_state=123, verbose=0, warm_start=False)

# %%
predict_model(tuned_rf);
# Out:
# <style  type="text/css" >
# </style><table id="T_b1b56fd8_c948_11ec_b421_f3e8809ff066" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b1b56fd8_c948_11ec_b421_f3e8809ff066level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b1b56fd8_c948_11ec_b421_f3e8809ff066row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#                         <td id="T_b1b56fd8_c948_11ec_b421_f3e8809ff066row0_col1" class="data row0 col1" >0.6423</td>
#                         <td id="T_b1b56fd8_c948_11ec_b421_f3e8809ff066row0_col2" class="data row0 col2" >0.9489</td>
#                         <td id="T_b1b56fd8_c948_11ec_b421_f3e8809ff066row0_col3" class="data row0 col3" >0.6310</td>
#                         <td id="T_b1b56fd8_c948_11ec_b421_f3e8809ff066row0_col4" class="data row0 col4" >0.6782</td>
#                         <td id="T_b1b56fd8_c948_11ec_b421_f3e8809ff066row0_col5" class="data row0 col5" >0.6400</td>
#                         <td id="T_b1b56fd8_c948_11ec_b421_f3e8809ff066row0_col6" class="data row0 col6" >0.6121</td>
#                         <td id="T_b1b56fd8_c948_11ec_b421_f3e8809ff066row0_col7" class="data row0 col7" >0.6163</td>
#             </tr>
#     </tbody></table>

# %%
unseen_predictions = predict_model(tuned_rf, data=data_unseen)
unseen_predictions
# Out:
#      Year  Country            Commodity  Apparent use (THOUSAND TONS)  \
# 0    2007  Austria       ACIDIFIED MILK                    167.148385
# 1    2009  Austria       ACIDIFIED MILK                    170.162800
# 2    2015  Austria       ACIDIFIED MILK                    159.344447
# 3    2019  Austria       ACIDIFIED MILK                    189.208348
# 4    2015  Austria  BUTTER (80-90% FAT)                     40.329237
# ..    ...      ...                  ...                           ...
# 193  2006   Sweden         TOTAL BUTTER                     21.536182
# 194  2011   Sweden         TOTAL BUTTER                     37.371512
# 195  2017   Sweden         TOTAL BUTTER                     51.775808
# 196  2011   Sweden         TOTAL CHEESE                    184.084543
# 197  2020   Sweden         TOTAL CHEESE                    204.460127
#
#      Production (THOUSAND TONS)  Exports (Extra-EU) (THOUSAND TONS)  \
# 0                    281.430000                            4.805000
# 1                    286.930000                            7.464700
# 2                    256.220000                            1.985631
# 3                    263.940000                            4.941875
# 4                     32.500000                            0.156609
# ..                          ...                                 ...
# 193                   41.750000                           11.769405
# 194                   25.360000                            0.233864
# 195                   40.566845                            0.200792
# 196                  103.300000                            1.788916
# 197                   83.480000                            1.389547
#
#      Exports (Intra-EU) (THOUSAND TONS)  Imports (Extra-EU) (THOUSAND TONS)  \
# 0                            137.659200                            0.015600
# 1                            142.125200                            0.173200
# 2                            124.178947                            0.022879
# 3                             94.773073                            0.035298
# 4                              3.799054                            0.000016
# ..                                  ...                                 ...
# 193                           15.351807                            0.039819
# 194                            1.630958                            0.000433
# 195                            1.698735                            0.008723
# 196                           13.171802                            1.855241
# 197                           16.339162                            2.923135
#
#      Imports (Intra-EU) (THOUSAND TONS)     Label   Score
# 0                             28.166985   Austria  0.1388
# 1                             32.649500   Austria  0.1339
# 2                             29.266146   Austria  0.1344
# 3                             24.947998   Austria  0.1288
# 4                             11.784884  Slovakia  0.1447
# ..                                  ...       ...     ...
# 193                            6.867575  Portugal  0.1162
# 194                           13.875901   Austria  0.1121
# 195                           13.099767   Austria  0.1134
# 196                           93.890020    Sweden  0.1502
# 197                          135.785701    Sweden  0.1733
#
# [198 rows x 11 columns]

# %% [markdown]
# ## Regression

# %%
data = df.sample(frac=0.9, random_state=786)
data_unseen = df.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (1778, 9)
# Unseen Data For Predictions: (198, 9)

# %%
from pycaret.regression import *

# %%
from pycaret.regression import *
exp_reg101 = setup(data = data, target = 'Apparent use (THOUSAND TONS)', session_id=123)
# Out:
# <style  type="text/css" >
# </style><table id="T_283d509c_c949_11ec_94db_f3e8809ff066" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row1_col1" class="data row1 col1" >Apparent use (THOUSAND TONS)</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row2_col1" class="data row2 col1" >(1778, 9)</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row4_col1" class="data row4 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row5_col1" class="data row5 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row9_col1" class="data row9 col1" >(1244, 45)</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row10_col1" class="data row10 col1" >(534, 45)</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_283d509c_c949_11ec_94db_f3e8809ff066level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_283d509c_c949_11ec_94db_f3e8809ff066row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>

# %%
best = compare_models(exclude = ['ransac'])
# Out:
# <style  type="text/css" >
#     #T_5dd18398_c949_11ec_9ea6_f3e8809ff066 th {
#           text-align: left;
#     }#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row0_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row0_col1,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row0_col3,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row1_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row1_col1,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row1_col2,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row1_col3,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row1_col5,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row1_col6,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row2_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row2_col1,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row2_col3,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row3_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row3_col1,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row3_col2,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row3_col3,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row3_col5,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row3_col6,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row4_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row5_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row5_col1,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row5_col2,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row5_col3,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row5_col5,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row5_col6,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row6_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row6_col1,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row6_col3,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row6_col5,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row6_col6,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row7_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row7_col1,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row7_col2,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row7_col3,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row7_col4,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row7_col5,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row7_col6,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row8_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row8_col1,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row8_col2,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row8_col3,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row8_col4,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row8_col5,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row8_col6,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row9_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row9_col1,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row9_col2,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row9_col3,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row9_col4,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row9_col5,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row9_col6,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row10_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row10_col1,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row10_col2,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row10_col3,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row10_col4,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row10_col5,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row10_col6,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row11_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row11_col1,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row11_col2,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row11_col3,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row11_col4,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row11_col5,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row11_col6,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row12_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row12_col1,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row12_col2,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row12_col3,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row12_col4,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row12_col5,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row12_col6,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row13_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row13_col1,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row13_col2,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row13_col3,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row13_col4,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row13_col5,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row13_col6,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row14_col0,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row14_c ...
#             text-align:  left;
#             text-align:  left;
#         }#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row0_col2,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row0_col4,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row0_col5,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row0_col6,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row1_col4,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row2_col2,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row2_col4,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row2_col5,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row2_col6,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row3_col4,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row4_col1,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row4_col2,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row4_col3,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row4_col4,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row4_col5,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row4_col6,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row5_col4,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row6_col2,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row6_col4{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row0_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row1_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row2_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row3_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row4_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row5_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row6_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row7_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row9_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row10_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row11_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row12_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row13_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row14_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row15_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row16_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row17_col7,#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_5dd18398_c949_11ec_9ea6_f3e8809ff066row8_col7{
#             text-align:  left;
#             text-align:  left;

# %%
lr = create_model('lr')
# Out:
# <style  type="text/css" >
# #T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row10_col0,#T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row10_col1,#T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row10_col2,#T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row10_col3,#T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row10_col4,#T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row10_col5{
#             background:  yellow;
#         }</style><table id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row0_col0" class="data row0 col0" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row0_col1" class="data row0 col1" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row0_col2" class="data row0 col2" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row0_col3" class="data row0 col3" >1.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row0_col4" class="data row0 col4" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row0_col5" class="data row0 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row1_col0" class="data row1 col0" >0.0001</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row1_col1" class="data row1 col1" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row1_col2" class="data row1 col2" >0.0001</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row1_col3" class="data row1 col3" >1.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row1_col4" class="data row1 col4" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row1_col5" class="data row1 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row2_col0" class="data row2 col0" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row2_col1" class="data row2 col1" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row2_col2" class="data row2 col2" >0.0001</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row2_col3" class="data row2 col3" >1.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row2_col4" class="data row2 col4" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row2_col5" class="data row2 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row3_col0" class="data row3 col0" >0.0001</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row3_col1" class="data row3 col1" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row3_col2" class="data row3 col2" >0.0002</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row3_col3" class="data row3 col3" >1.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row3_col4" class="data row3 col4" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row3_col5" class="data row3 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row4_col0" class="data row4 col0" >0.0001</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row4_col1" class="data row4 col1" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row4_col2" class="data row4 col2" >0.0001</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row4_col3" class="data row4 col3" >1.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row4_col4" class="data row4 col4" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row4_col5" class="data row4 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row5_col0" class="data row5 col0" >0.0001</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row5_col1" class="data row5 col1" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row5_col2" class="data row5 col2" >0.0001</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row5_col3" class="data row5 col3" >1.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row5_col4" class="data row5 col4" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row5_col5" class="data row5 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row6_col0" class="data row6 col0" >0.0001</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row6_col1" class="data row6 col1" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row6_col2" class="data row6 col2" >0.0001</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row6_col3" class="data row6 col3" >1.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row6_col4" class="data row6 col4" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row6_col5" class="data row6 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row7_col0" class="data row7 col0" >0.0001</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row7_col1" class="data row7 col1" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row7_col2" class="data row7 col2" >0.0001</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row7_col3" class="data row7 col3" >1.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row7_col4" class="data row7 col4" >0.0000</td>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row7_col5" class="data row7 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_8c4fbcc2_c949_11ec_90ed_f3e8809ff066row8_col0" class="data row8 col0" >0.0001</td>
#                         <td id

# %% [markdown]
# Dataset Insights
#
# We have **no Missing Data** in any feature
#
# **STATUS** feature has constant value "Open"   (does not add value to analysis)
#
# **STATION ID** is a unique identifier of each Station (does not add value to analysis)
#
# **ADDRESS** has a high cardinality: 109 distinct values (does not add value to analysis once we have Lat and Long)
#
# **AVAILABLE BIKES** is the only feature that presents outliers (around 1% of the values are considered outliers), however I could not find any values over 40 as that is the maximum possible value once there are no Bike stations with more than 40 stands.
#
# It was not possible to find evidence of errors since in none of the observations the number of bicycles available at the station was greater than the total number of Stands.
# For that reason I am going to consider the outliers acceptable and part of the nature of the operation of the business.
#
# **AVAILABLE BIKE STANDS** is skewed but close to Normal Distribution.

# %% [markdown]
# ## Statistics Questions

# %% [markdown]
# ## Data Preparation and Feature engineering

# %% [markdown]
# ## Re-Shaping Data and Build M Learning Models

# %% [markdown]
# ## Dimensionality Reduction using Principal Components Analyses

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Upon review, I found that the CRISP_DM framework is an excellent tool to keep focus on the tasks at hand and I will seek to make use of this in future projects.
#
# Prior to signing off on this project, reassessments were made to ensure that all proposals and objectives initially addressed were met and that all questions were answered appropriately with sufficient evidence and rationale for decisions made .
#
# It is evident that Data Science applied in any dataset can help us to better understand the world and make better decisions as human beings, with a mindset of recognising the impacts for future generations.
#
# Some points to highlight regarding this assessment is the importance of:
# •	having a good methodology.
# •	having the right tools available.
# •	discipline for reading, researching, and developing skills and the necessary knowledge in Programming, Statistics, Data Preparation, Machine Learning and Data Visualization.
#
# With the project findings presented, it is clear that further research could be made to progress more about the topic. There are clearly some correlations between the different groups of Dublin Bike Stations and maybe opportunities for a better distribution of the Bikes among the stations to improve the service provided. This might become a topic for future discussions.

# %% [markdown]
# ## References:

# %% [markdown]
# Agresti, A. and Kateri, M. (2021). Foundations of statistics for data scientists : with R and Python. First Edition ed. Boca Raton: Crc Press.
#
# Bhardwaj, A. (2020). Silhouette Coefficient : Validating clustering techniques. [online] Medium. Available at: https://towardsdatascience.com/silhouette-coefficient-validating-clustering-techniques-e976bb81d10c
#
# Blackmist (n.d.). Train and deploy a reinforcement learning model (preview) - Azure Machine Learning. [online] docs.microsoft.com. Available at: https://docs.microsoft.com/en-us/azure/machine-learning/how-to-use-reinforcement-learning
#
# Breslin, R. (2020). What Dublin Bikes data can tell us about the city and its people. [online] Medium. Available at: https://towardsdatascience.com/what-dublin-bikes-data-can-tell-us-about-the-city-and-its-people-63fde77ee383
#
# C Wilke (2019). Fundamentals of data visualization : a primer on making informative and compelling figures. Sebastopol, Ca: O’reilly Media.
#
# Chun-Houh Chen and Al, E. (2016). Handbook of data visualization. Berlin: Springer.
#
# Connors, L. (2021). Creating a Simple Map with Folium and Python. [online] Medium. Available at: https://towardsdatascience.com/creating-a-simple-map-with-folium-and-python-4c083abfff94
#
# Das, A. (2020). Hierarchical Clustering in Python using Dendrogram and Cophenetic Correlation. [online] Medium. Available at: https://towardsdatascience.com/hierarchical-clustering-in-python-using-dendrogram-and-cophenetic-correlation-8d41a08f7eab
#
# data.smartdublin.ie. (n.d.). Dublinbikes DCC - data.smartdublin.ie. [online] Available at: https://data.smartdublin.ie/dataset/analyze/33ec9fe2-4957-4e9a-ab55-c5e917c7a9ab
#
# dataprep.ai. (n.d.). DataPrep — The easiest way to prepare data in Python. [online] Available at: https://dataprep.ai/
#
# fontawesome.com. (n.d.). Font Awesome. [online] Available at: https://fontawesome.com/icons?d=gallery
#
# Galarnyk, M. (2017). PCA using Python (scikit-learn). [online] Medium. Available at: https://towardsdatascience.com/pca-using-python-scikit-learn-e653f8989e60
#
# GeeksforGeeks. (2021). What is Data Visualization and Why is It Important? [online] Available at: https://www.geeksforgeeks.org/what-is-data-visualization-and-why-is-it-important/#:~:text=Data%20visualization%20is%20very%20critical%20to%20market%20research
#
# Grus, J. (2021). DATA SCIENCE FROM SCRATCH : first principles with python. Second ed. O’Reilly.
#
# IBM Cloud Education (2020a). What is Exploratory Data Analysis? [online] www.ibm.com. Available at: https://www.ibm.com/cloud/learn/exploratory-data-analysis.
#
# IBM Cloud Education (2020b). What is Machine Learning? [online] www.ibm.com. Available at: https://www.ibm.com/cloud/learn/machine-learning
#
# James (2017). Usage patterns of Dublin Bikes stations. [online] Medium. Available at: https://towardsdatascience.com/usage-patterns-of-dublin-bikes-stations-484bdd9c5b9e
#
# Jeffares, A. (2019). How I used Machine Learning to improve my Dublin Bikes transit. [online] Medium. Available at: https://towardsdatascience.com/how-i-used-machine-learning-to-improve-my-dublin-bikes-transit-b6bdc7c2b5cb
#
# Jeffares, A. (2021a). Data Science Nanodegree. [online] GitHub. Available at: https://github.com/alanjeffares/data-science-nanodegree/blob/master/dublin-bikes-analysis/get_nearest_available_bike.py
#
# Jeffares, A. (2021b). Data Science Nanodegree. [online] GitHub. Available at: https://github.com/alanjeffares/data-science-nanodegree/blob/master/dublin-bikes-analysis/data_load_processing_viz.ipynb
#
# Lawlor, J. (2021). dublin-bikes-timeseries-analysis. [online] GitHub. Available at: https://github.com/jameslawlor/dublin-bikes-timeseries-analysis
#
# Martinez, J.C. (2021). How to plot your data on maps using Python and Folium. [online] livecodestream.dev. Available at: https://livecodestream.dev/post/how-to-plot-your-data-on-maps-using-python-and-folium/
#
# Mckinney, W. (2018). Python for data analysis : data wrangling with pandas, NumPy, and IPython. Second ed. Sebastopol, Ca: O’reilly Media, Inc., October.
#
# Müller, A.C. and Guido, S. (2017). Introduction to machine learning with Python : a guide for data scientists. Beijing: O’reilly.
#
# Nichani, P. (2020). OutLiers in Machine Learning. [online] Analytics Vidhya. Available at: https://medium.com/analytics-vidhya/outliers-in-machine-learning-e830b2bd8660#:~:text=Outlier%20is%20an%20observation%20that%20appears%20far%20away
#
# plotlygraphs (2019). Line Charts. [online] plotly.com. Available at: https://plotly.com/python/line-charts/
#
# rachelbreslin (2022). dublin_bikes/Dublin Bikes Analysis.ipynb at main · rachelbreslin/dublin_bikes. [online] GitHub. Available at: https://github.com/rachelbreslin/dublin_bikes/blob/main/Dublin%20Bikes%20Analysis.ipynb
#
# Ranjan, A. (2020). Hierarchical Clustering (Agglomerative). [online] Analytics Vidhya. Available at: https://medium.com/analytics-vidhya/hierarchical-clustering-agglomerative-f6906d440981
#
# scikit-learn.org (n.d.). sklearn.metrics.adjusted_rand_score — scikit-learn 0.23.1 documentation. [online] scikit-learn.org. Available at: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.adjusted_rand_score.html
#
# Scikit-learn.org. (2019). sklearn.preprocessing.StandardScaler — scikit-learn 0.21.2 documentation. [online] Available at: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
#
# Summerfield, M. (2010). Programming in Python 3 : a complete introduction to the Python language. Second ed. Upper Saddle River, New Jersey: Addison-Wesley.
#
# Weiss, N.A. (2017). Introductory Statistics. 10th ed. Pearson Education.
#
# Wilke, C.O. (n.d.). Fundamentals of Data Visualization. [online] clauswilke.com. Available at: https://clauswilke.com/dataviz/directory-of-visualizations.html.
#
# www.dublinbikes.ie. (n.d.). DublinBikes. [online] Available at: https://www.dublinbikes.ie/
#
# www.ibm.com. (n.d.). CRISP-DM Help Overview. [online] Available at: https://www.ibm.com/docs/en/spss-modeler/SaaS?topic=dm-crisp-help-overview.
#
# www.youtube.com. (2018). PyData Dublin: Usage patterns of Dublin Bikes stations - James Lawlor. [online] Available at: https://www.youtube.com/watch?v=59ck_Z75cEY
